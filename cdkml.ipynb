# %% [markdown]
# <a href="https://colab.research.google.com/github/napolitanodst/diana/blob/main/cdkml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Download compounds with inhibitory activity against CDK5

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/napolitanodst/diana/main/cdk5%20inhibitors.csv", sep=";")
df
# Out:
#           ChEMBL ID                     Name  \
# 0     CHEMBL4110764                      NaN
# 1     CHEMBL1256351               FENCLONINE
# 2         CHEMBL414                CARZENIDE
# 3      CHEMBL507322                      NaN
# 4       CHEMBL64706                ORBOFIBAN
# ...             ...                      ...
# 2084  CHEMBL3989962  PEMETREXED TROMETHAMINE
# 2085      CHEMBL563             FLURBIPROFEN
# 2086      CHEMBL812   PYRIDOSTIGMINE BROMIDE
# 2087     CHEMBL1115           PYRIDOSTIGMINE
# 2088  CHEMBL3989861  DESVENLAFAXINE FUMARATE
#
#                                                Synonyms            Type  \
# 0                                                   NaN  Small molecule
# 1     CP-10,188|CP-10188|FENCLONINE|NSC-77370|P-CHLO...  Small molecule
# 2     4-SULFAMOLYBENZOIC ACID|CARZENIDE|Carzenide|NS...  Small molecule
# 3                                                   NaN  Small molecule
# ...
